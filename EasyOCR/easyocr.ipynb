# %%
# show an image
import PIL
from PIL import ImageDraw
im = PIL.Image.open("vn.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=260x205 at 0x7F9B58237E20>

# %%
import easyocr
reader = easyocr.Reader(['vi','en'])
bounds = reader.readtext('vn.png')
bounds
# Out:
# [([[57, 13], [211, 13], [211, 49], [57, 49]],
#   'SÁN BAV TRù NóC',
#   0.05148572102189064),
#  ([[161, 45], [260, 45], [260, 81], [161, 81]],
#   'TRUING TÂM',
#   0.2587743103504181),
#  ([[76, 46], [118, 46], [118, 70], [76, 70]], 'TKm', 0.6070356965065002),
#  ([[7, 77], [105, 77], [105, 113], [7, 113]], 'SóC TRÁNG', 0.3221479654312134),
#  ([[159, 77], [260, 77], [260, 113], [159, 113]],
#   'TP. CÁN THO',
#   0.07930419594049454),
#  ([[16, 108], [68, 108], [68, 134], [16, 134]], 'G7Km', 0.878423810005188),
#  ([[212, 108], [254, 108], [254, 132], [212, 132]], '2Km', 0.6902047395706177)]

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=260x205 at 0x7F9B58237E20>
